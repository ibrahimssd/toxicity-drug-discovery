# %%
# %load_ext autoreload
# %autoreload 2

# %%
import selfies as sf
from selfies import encoder, DecoderError
import pandas as pd
from rdkit import Chem
from rdkit.Chem import Draw
import logging
import pickle
from data_preprocess import DataPreprocessor
from utils import read_segmented_mols, smiles_to_text, selfies_to_text , smiles_fragments_to_selfies_fragments , build_vocab
from tokenization_algorithms.MacFragger import MacFragGenerator
from tokenization_algorithms.spe import SMILESLearner
from utils import *
import codecs
from SmilesPE.tokenizer import *

# %%
# create a data preprocessor object to preprocess clintox dataset (create SELFIES and SMILES with corresponding target)
clintox_preprocessor = DataPreprocessor(input='datasets/clintox.csv', output='datasets/pre_processed', target='CT_TOX', name='clintox')
tox21_preprocessor = DataPreprocessor(input='datasets/tox21.csv', output='datasets/pre_processed', target='NR-AR', name='tox21')
clintox_data = clintox_preprocessor.pre_process()
tox21_data = tox21_preprocessor.pre_process()
# Transfer SMILES and SELFIES to text files 
smiles_to_text(dataframe = clintox_data,output_file= 'datasets/pre_processed/clintox.smi')
smiles_to_text(dataframe = tox21_data,output_file= 'datasets/pre_processed/tox21.smi')
selfies_to_text(dataframe = clintox_data, output_file='datasets/pre_processed/clintox.selfi')
selfies_to_text(dataframe = tox21_data,output_file= 'datasets/pre_processed/tox21.selfi')
# Out:
# Pre-processing clintox dataset...
# Number Of processed SMILES: 1484
# Number of removed SMILES: 8
# Number of valid SMILES: 1476
# Number of positive samples: 112
# Number of negative samples: 1364
# Percentage of positive samples: 7.588075880758808 %
# Percentage of negative samples: 92.41192411924119 %
# saving  clintox dataset to CSV file...
# saving  clintox dataset SMILES to TXT file...
# Pre-processing tox21 dataset...
# Number Of processed SMILES: 3079
# Number of removed SMILES: 0
# Number of valid SMILES: 3079
# Number of positive samples: 59
# Number of negative samples: 3020
# Percentage of positive samples: 1.916206560571614 %
# Percentage of negative samples: 98.08379343942839 %
# saving  tox21 dataset to CSV file...
# saving  tox21 dataset SMILES to TXT file...

# %%
# Mc fragger tokenization
macFragger = MacFragGenerator()
# clintoxt dataset
input_file = './datasets/pre_processed/clintox.smi'
dir = './datasets/mac_fragments/'
asMols = False
maxBlocks = 6
maxSR = 8
minFragAtoms = 1
name = 'clintox'
macFragger.write_file(input_file, dir, maxBlocks, maxSR, asMols, minFragAtoms, name)
# tox21 dataset
input_file = './datasets/pre_processed/tox21.smi'
dir = './datasets/mac_fragments/'
asMols = False
maxBlocks = 6
maxSR = 8
minFragAtoms = 1
name = 'tox21'
macFragger.write_file(input_file, dir, maxBlocks, maxSR, asMols, minFragAtoms, name)

# zinc dataset
input_file = './datasets/zinc.smi'
dir = './datasets/mac_fragments/'
asMols = False
maxBlocks = 6
maxSR = 8
minFragAtoms = 1
name = 'zinc'
macFragger.write_file(input_file, dir, maxBlocks, maxSR, asMols, minFragAtoms, name)


# smilesDB dataset
input_file = './datasets/smilesDB.smi'
dir = './datasets/mac_fragments/'
asMols = False
maxBlocks = 6
maxSR = 8
minFragAtoms = 1
name = 'smilesDB'
macFragger.write_file(input_file, dir, maxBlocks, maxSR, asMols, minFragAtoms, name)
# Out:
# non_mols:  0
# processed_mols:  1476
# non_mols:  0
# processed_mols:  3079
# non_mols:  0
# processed_mols:  249455
# Error: the input file contains non-mols
# Error: the input file contains non-mols
# Error: the input file contains non-mols
# Error: the input file contains non-mols
# Error: the input file contains non-mols
# Error: the input file contains non-mols
# non_mols:  6
# processed_mols:  258764

# %%
#build vocabulary for Mac Fragger fragments
special_tokens = ['[PAD]', 
                '[unused1]', '[unused2]', '[unused3]', '[unused4]','[unused5]', '[unused6]', '[unused7]', '[unused8]', '[unused9]', '[unused10]', 
                '[UNK]', '[CLS]', '[SEP]', '[MASK]']
 # clintox dataset
input= './datasets/mac_fragments/clintox_fragments.smi'
output = './vocabs/macFrag_vocab/clintox_vocab.smi'
build_vocab(input,output, special_tokens=special_tokens)
# tox21 dataset
input= './datasets/mac_fragments/tox21_fragments.smi'
output = './vocabs/macFrag_vocab/tox21_vocab.smi'
build_vocab(input,output, special_tokens=special_tokens)
# zinc dataset
input= './datasets/mac_fragments/zinc_fragments.smi'
output = './vocabs/macFrag_vocab/zinc_vocab.smi'
build_vocab(input,output, special_tokens=special_tokens)
# smilesDB dataset
input= './datasets/mac_fragments/smilesDB_fragments.smi'
output = './vocabs/macFrag_vocab/smilesDB_vocab.smi'
build_vocab(input,output, special_tokens=special_tokens)

# %%
# train spe , BPE encoder on smiles
vocab_size = 1_000
input_file = './datasets/cleaned_smilesDB.smi'
output_file = './vocabs/spe_vocab/cleaned_smilesDB' + '_' + str(vocab_size) + '.smi'
spe_learner = SMILESLearner(file_name=input_file, output_file=output_file,num_symbols= vocab_size, min_frequency=1, augmentation=1, verbose=True, total_symbols=True)
spe_smi ,spe_smi_vocab = spe_learner.learn_SMILES()
bpe_smi , bpe_smi_vocab= spe_learner.learn_BPE()
# save model
save_model(bpe_smi, './models/tokenizers/bpe_DBsmi_1000.bin') # already saved while training
# train spe encoder on selfies
input_file = "./datasets/cleaned_selfiesDB.self"
output_file = "./vocab/spe_vocab/cleaned_selfiesDB" + '_' + str(vocab_size) + '.self'
spe_learner = SMILESLearner(file_name=input_file, output_file=output_file,num_symbols= vocab_size, min_frequency=1)
bpe_self , bpe_self_vocab = spe_learner.learn_BPE()
# save picle models
save_model(bpe_self, './models/tokenizers/bpe_DBself_1000.bin')
# train ByteLevelBPETokenizer on smiles
from tokenizers.implementations import ByteLevelBPETokenizer
tokenizer = ByteLevelBPETokenizer()
tokenizer.train(files='./datasets/smilesDB.smi', vocab_size=vocab_size, min_frequency=1)
tokenizer.save_model('./models/tokenizers/ByteLevelBPETokenizer')
save_model(tokenizer, './models/tokenizers/ByteLevelBPETokenizer.bin')
# Out:
# ['./models/tokenizers/ByteLevelBPETokenizer/vocab.json',
#  './models/tokenizers/ByteLevelBPETokenizer/merges.txt']

# %%
print(tokenizer.encode('COC(=O)c1c(N2C(=O)[C@@H]3[C@@H]4CCC[NH+]4[C@@]4(C(=O)Nc5c(C)cc(C)cc54)[C@@H]3C2=O)sc(C)c1C').tokens)
# load Bpe tokenizers 
bpe_smi = load_model('models/tokenizers/bpe_DBsmi_1000.bin')
bpe_self = load_model('models/tokenizers/bpe_DBself_1000.bin')
print(bpe_smi.encode('COC(=O)c1c(N2C(=O)[C@@H]3[C@@H]4CCC[NH+]4[C@@]4(C(=O)Nc5c(C)cc(C)cc54)[C@@H]3C2=O)sc(C)c1C').tokens)
# Load ByteLevelBPETokenizer's tokenizer
byteLevelBPETokenizer = load_model('models/tokenizers/ByteLevelBPETokenizer.bin')
print(byteLevelBPETokenizer.encode('COC(=O)c1c(N2C(=O)[C@@H]3[C@@H]4CCC[NH+]4[C@@]4(C(=O)Nc5c(C)cc(C)cc54)[C@@H]3C2=O)sc(C)c1C').tokens)
# load spe 
spe_vob= codecs.open('./vocabs/spe_vocab/cleaned_smilesDB_1000.smi')
spe = SPE_Tokenizer(spe_vob)
print(spe.tokenize('COC(=O)c1c(N2C(=O)[C@@H]3[C@@H]4CCC[NH+]4[C@@]4(C(=O)Nc5c(C)cc(C)cc54)[C@@H]3C2=O)sc(C)c1C'))
# Out:
# ['COC', '(=', 'O', ')', 'c', '1', 'c', '(', 'N', '2', 'C', '(=', 'O', ')[', 'C', '@@', 'H', ']', '3', '[', 'C', '@@', 'H', ']', '4', 'CCC', '[', 'NH', '+]', '4', '[', 'C', '@@]', '4', '(', 'C', '(=', 'O', ')', 'Nc', '5', 'c', '(', 'C', ')', 'cc', '(', 'C', ')', 'cc', '54', ')[', 'C', '@@', 'H', ']', '3', 'C', '2', '=', 'O', ')', 'sc', '(', 'C', ')', 'c', '1', 'C']
# ['COC(=O)', 'c1c(N', '2C(=O)', '[C@@H]3', '[C@@H]4CCC', '[NH+]4', '[C@@]4(C(=O)N', 'c5', 'c(C)cc(C)cc', '5', '4)[C@@H]3C', '2=O)', 's', 'c(C)c1C']
# ['COC', '(=', 'O', ')', 'c', '1', 'c', '(', 'N', '2', 'C', '(=', 'O', ')[', 'C', '@@', 'H', ']', '3', '[', 'C', '@@', 'H', ']', '4', 'CCC', '[', 'NH', '+]', '4', '[', 'C', '@@]', '4', '(', 'C', '(=', 'O', ')', 'Nc', '5', 'c', '(', 'C', ')', 'cc', '(', 'C', ')', 'cc', '54', ')[', 'C', '@@', 'H', ']', '3', 'C', '2', '=', 'O', ')', 'sc', '(', 'C', ')', 'c', '1', 'C']
# COC(=O) c1c( N2C(=O) [C@@H]3 [C@@H] 4 CCC [NH+] 4 [C@@] 4 (C(=O)N c5 c(C)cc (C)cc 5 4) [C@@H]3 C2=O) s c(C) c1C

# %%
# save tokenizers models
# bpe_smi2.save('./models/tokenizers/bpe_smi2.bin')
# bpe_self.save('./models/tokenizers/bpe_self.bin')
# some default tokens from huggingface
default_toks = ['[PAD]', 
                '[unused1]', '[unused2]', '[unused3]', '[unused4]','[unused5]', '[unused6]', '[unused7]', '[unused8]', '[unused9]', '[unused10]', 
                '[UNK]', '[CLS]', '[SEP]', '[MASK]']

# atom-level tokens used for trained the spe vocabulary
atom_toks = ['[c-]', '[SeH]', '[N]', '[C@@]', '[Te]', '[OH+]', 'n', '[AsH]', '[B]', 'b', 
             '[S@@]', 'o', ')', '[NH+]', '[SH]', 'O', 'I', '[C@]', '-', '[As+]', '[Cl+2]', 
             '[P+]', '[o+]', '[C]', '[C@H]', '[CH2]', '\\', 'P', '[O-]', '[NH-]', '[S@@+]', 
             '[te]', '[s+]', 's', '[B-]', 'B', 'F', '=', '[te+]', '[H]', '[C@@H]', '[Na]', 
             '[Si]', '[CH2-]', '[S@+]', 'C', '[se+]', '[cH-]', '6', 'N', '[IH2]', '[As]', 
             '[Si@]', '[BH3-]', '[Se]', 'Br', '[C+]', '[I+3]', '[b-]', '[P@+]', '[SH2]', '[I+2]', 
             '%11', '[Ag-3]', '[O]', '9', 'c', '[N-]', '[BH-]', '4', '[N@+]', '[SiH]', '[Cl+3]', '#', 
             '(', '[O+]', '[S-]', '[Br+2]', '[nH]', '[N+]', '[n-]', '3', '[Se+]', '[P@@]', '[Zn]', '2', 
             '[NH2+]', '%10', '[SiH2]', '[nH+]', '[Si@@]', '[P@@+]', '/', '1', '[c+]', '[S@]', '[S+]', 
             '[SH+]', '[B@@-]', '8', '[B@-]', '[C-]', '7', '[P@]', '[se]', 'S', '[n+]', '[PH]', '[I+]', '5', 'p', '[BH2-]', '[N@@+]', '[CH]', 'Cl']

# build spe vocab 

# spe tokens
with open('./vocabs/spe_vocab/cleaned_smilesDB' + '_' + str(vocab_size) + '.smi', "r") as ins:
    spe_toks = []
    for line in ins:
        spe_toks.append(line.split('\n')[0])
        

spe_tokens = []
for s in spe_toks:
    spe_tokens.append(''.join(s.split(' ')))
print('Number of SMILES:', len(spe_toks))
# build the vocabulary for the spe tokenizer
print(spe_tokens[:10])
spe_vocab = default_toks + atom_toks + spe_tokens
print('Number of tokens:', len(spe_vocab))
# save the vocabulary
with open('./vocabs/spe_vocab/vocab_speSMILESDB' + '_' + str(vocab_size) + '.txt', 'w') as f:
    for voc in spe_vocab:
        f.write(f'{voc}\n')

print("################################################################")
# build vocab for Bpe tokenizers
# build Bpe vocab
vocab_path = './vocabs/bpe_vocab/'
# write bpe_smi2 vocab file
vocs = list(default_toks) + list(bpe_smi_vocab.keys()) 
with open(vocab_path + 'bpe_DBsmi_vocab_' + str(vocab_size) + '.txt', 'w') as f:
    for voc in vocs:
        f.write(f'{voc.strip()}\n')


# write bpe_self vocab file
vocs = list(default_toks) + list(bpe_self_vocab.keys())
with open(vocab_path + 'bpe_DBself_vocab_' + str(vocab_size) + '.txt', 'w') as f:
    for voc in bpe_self_vocab:
        f.write(f'{voc.strip()}\n')
# Out:
# Number of SMILES: 851
# ['cc', 'CC', '(C', 'c1', 'O)', '=O)', '(=O)', 'c2', '(C)', 'c(']
# Number of tokens: 981
# ################################################################

# %%
# build vocab for morfessor tokenizers
# some default tokens from huggingface
morf_model_pt='models/tokenizers/morf_smilesDB_1000.bin' #'models/tokenizers/morf_zinc_1000.bin'
morf_vocab_pt = './vocabs/morf_vocab/morf_smilesDB_vocab1000.txt' # './vocabs/morf_vocab/morf_zinc250k_vocab1000.txt'

default_toks = ['[PAD]', 
                '[unused1]', '[unused2]', '[unused3]', '[unused4]','[unused5]', '[unused6]', '[unused7]', '[unused8]', '[unused9]', '[unused10]', 
                '[UNK]', '[CLS]', '[SEP]', '[MASK]']
chem_morfessor= pickle.load(open(morf_model_pt, 'rb'))
print(chem_morfessor.viterbi_segment('C([C@@H]1[C@H]([C@@H]([C@H]([C@@H](O1)O[C@]2([C@H]([C@@H]([C@H](O2)OS(=O)(=O)O[Al](O)O)OS(=O)(=O)O[Al](O)O)OS(=O)(=O)O[Al](O)O)COS(=O)(=O)O[Al](O)O)OS(=O)(=O)O[Al](O)O)OS(=O)(=O)O[Al](O)O)OS(=O)(=O)O[Al](O)O)OS(=O)(=O)O[Al](O)O')[0])
print(len(chem_morfessor.get_constructions()))
constructions  = list(map(lambda t: t[0], chem_morfessor.get_constructions()))
# buil  vocab file
vocs = list(default_toks) + list(constructions)
with open(morf_vocab_pt, 'w') as f:
    for voc in vocs:
        f.write(f'{voc}\n')
# Out:
# ['C', '(', '[C@@H]1', '[C@H](', '[C@@H](', '[C@H](', '[C@@H](', 'O', '1)', 'O', '[C@]2(', '[C@H](', '[C@@H](', '[C@H](', 'O', '2)', 'O', 'S(=O)(=O)', 'O', '[', 'A', 'l', ']', '(O)', 'O', ')', 'O', 'S(=O)(=O)', 'O', '[', 'A', 'l', ']', '(O)', 'O', ')', 'O', 'S(=O)(=O)', 'O', '[', 'A', 'l', ']', '(O)', 'O', ')', 'C', 'O', 'S(=O)(=O)', 'O', '[', 'A', 'l', ']', '(O)', 'O', ')', 'O', 'S(=O)(=O)', 'O', '[', 'A', 'l', ']', '(O)', 'O', ')', 'O', 'S(=O)(=O)', 'O', '[', 'A', 'l', ']', '(O)', 'O', ')', 'O', 'S(=O)(=O)', 'O', '[', 'A', 'l', ']', '(O)', 'O', ')', 'O', 'S(=O)(=O)', 'O', '[', 'A', 'l', ']', '(O)', 'O']
# 1002

# %%
chem_morfessor1= pickle.load(open('models/tokenizers/morf_zinc_1000.bin', 'rb'))
chem_morfessor2= pickle.load(open('models/tokenizers/morf_smilesDB_1000.bin', 'rb'))

print(chem_morfessor1.viterbi_segment('C([C@@H]1[C@H]([C@@H]([C@H]([C@H](O1)O[C@]2([C@H]([C@@H]([C@H](O2)CO)O)O)CO)O)O)O)O'))
print(chem_morfessor2.viterbi_segment('C([C@@H]1[C@H]([C@@H]([C@H]([C@H](O1)O[C@]2([C@H]([C@@H]([C@H](O2)CO)O)O)CO)O)O)O)O'))
# Out:
# (['C', '(', '[C@@H]1', '[C@H](', '[C@@H](', '[C@H](', '[C@H](', 'O', '1)', 'O', '[C@]2(', '[C@H](', '[C@@H](', '[C@H](', 'O', '2)', 'C', 'O', ')', 'O', ')', 'O', ')', 'C', 'O', ')', 'O', ')', 'O', ')', 'O', ')', 'O'], 135.78457592359314)
# (['C', '(', '[C@@H]1', '[C@H](', '[C@@H](', '[C@H](', '[C@H](', 'O', '1)', 'O', '[C@]2(', '[C@H](', '[C@@H](', '[C@H](', 'O', '2)', 'C', 'O', ')', 'O', ')', 'O', ')', 'C', 'O', ')', 'O', ')', 'O', ')', 'O', ')', 'O'], 134.99606192059179)

# %%
chem_morfessor= pickle.load(open('models/tokenizers/morf_tox21_1000.bin', 'rb'))
segments1 = chem_morfessor.viterbi_segment('C([C@@H]1[C@H]([C@@H]([C@H]([C@@H](O1)O[C@]2([C@H]([C@@H]([C@H](O2)OS(=O)(=O)O[Al](O)O)OS(=O)(=O)O[Al](O)O)OS(=O)(=O)O[Al](O)O)COS(=O)(=O)O[Al](O)O)OS(=O)(=O)O[Al](O)O)OS(=O)(=O)O[Al](O)O)OS(=O)(=O)O[Al](O)O)OS(=O)(=O)O[Al](O)O')[0]
segments2 = chem_morfessor.viterbi_segment('NC(=O)c1ccc[n+]([C@@H]2O[C@H](COP(=O)([O-])OP(=O)(O)OC[C@H]3O[C@@H](n4cnc5c(N)ncnc54)[C@H](O)[C@@H]3O)[C@@H](O)[C@H]2O)c1')[0]
constructions = chem_morfessor.get_constructions()
# check if segments are in the constructions
for seg in segments2:
    if seg not in constructions:
        print(seg)
        print('not in constructions')
        break
# Out:
# NC(=O)
# not in constructions

# %%
# checked later
# Get compounds once instead of calling it in every loop iteration
# compounds = chem_morfessor.get_compounds()
# clintox_df = pd.read_csv('./datasets/post_processed/clintox_processed_macFrag.csv')
# compounds = clintox_df['smiles'].tolist()
# print(len(compounds))
# # Use list comprehension for faster execution
# morfessor_smi = [chem_morfessor.viterbi_segment(compound)[0] for compound in compounds]

# # save segments in one list and add default tokens , then write to file
# import itertools
# morfessor_segs_1= list(itertools.chain.from_iterable(morfessor_smi))
# morfessor_segs_2 = list(itertools.chain(*morfessor_smi))
# print(len(morfessor_segs_1))
# print(len(morfessor_segs_2))
# print('constructions: ', len(chem_morfessor.get_constructions()))
# # remove redundancy from segments
# morfessor_segs = list(set(morfessor_segs_1))
# print(len(morfessor_segs))
# morfessor_segs = list(set(morfessor_segs_2))
# print(len(morfessor_segs))

# # write segments to file (build morfessor tokenizer)
# total_tokens = list(default_toks) + morfessor_segs
# with open('./vocabs/morf_vocab/morf_tox21_vocab.txt', 'w') as f:
#     for voc in total_tokens:
#         f.write(f'{voc}\n')

# morfessor_segs_1

# %%
#clintoxt dataset
fragmented_mols_smi = read_segmented_mols('./datasets/mac_fragments/clintox_fragments.smi')
# fragmented_mols_selfies = smiles_fragments_to_selfies_fragments(fragmented_mols_smi)
# add new column of fragments to dataframe before CT_TOX column
df_clin= pd.read_csv('datasets/pre_processed/clintox.csv')#clintox_data.copy()
# insert new colum to df_clin with name 'smi_fragments' and values from fragmented_mols_smi
df_clin['smi_mac_fragments'] = fragmented_mols_smi
# insert new colum to df_clin with name 'selfies_fragments' and values from fragmented_mols_selfies
# df_clin['selfies_fragments'] = fragmented_mols_selfies
# rearange columns order to smiles, fragments, CT_TOX
df_clin = df_clin[['smiles', 'smi_mac_fragments', 'selfies', 'CT_TOX']]
# save dataframe to csv file
df_clin.to_csv('./datasets/post_processed/clintox_processed.csv', index=False)
# tox21 dataset
fragmented_mols_smi = read_segmented_mols('datasets/mac_fragments/tox21_fragments.smi')
# fragmented_mols_selfies = smiles_fragments_to_selfies_fragments(fragmented_mols_smi)
# add new column of fragments to dataframe before NR-AR column
df_tox =  pd.read_csv('datasets/pre_processed/tox21.csv')#tox21_data.copy()
df_tox['smi_mac_fragments'] = fragmented_mols_smi
# df_tox['selfies_fragments'] = fragmented_mols_selfies
# rearange columns order to smiles, fragments, NR-AR
df_tox = df_tox[['smiles', 'smi_mac_fragments', 'selfies', 'NR-AR']]
# save dataframe to csv file
df_tox.to_csv('./datasets/post_processed/tox21_processed.csv', index=False)

# %%
df_clin['smi_mac_fragments'].tolist()
# Out:
# ['Cl[C@H]1[C@H](Cl)[C@@H](Cl)[C@@H](Cl)[C@H](Cl)[C@H]1Cl',
#  'O=C([O-])[C@@H](O)[C@@H](O)[C@H](O)[C@@H](O)C(=O)[O-]',
#  '[5*]=CC=c1ccc(=C(N)[NH3+])cc1,[5*]=C1C=CC(/C(N)=[NH+]/[H])=CC1=O',
#  '[2*]O[2*],[14*]c1ccc(/C(N)=[NH+]/[H])cc1,[3*]CCCCC[3*]',
#  'O=[N+]([O-])[O-]',
#  '[N]=O',
#  'O=[99Tc](=O)(=O)[O-]',
#  'O=P([O-])([O-])F',
#  'O=S(=O)([O-])[O-]',
#  'O=S([O-])([O-])=S',
#  '[Se]',
#  '[3*][C@@H](CC(C)C)B(O)O,[12*]c1cnccn1,[1*]C(=O)[C@@H]([3*])C[6*],[14*]c1ccccc1,[1*]C([1*])=O,[4*]N[4*]',
#  '[3*][C@@H](CC(C)C)B(O)O,[12*]c1cnccn1,[1*]C(=O)[C@@H]([3*])C[6*],[14*]c1ccccc1,[1*]C([1*])=O,[4*]N[4*]',
#  '[1*]C(=O)C[3*],[3*][C@@H](CC(C)C)B(O)O,[1*]C([1*])=O,[4*]N[4*],[14*]c1cc(Cl)ccc1Cl',
#  '[2*]O[2*],[1*]C(N)=O,[3*]C1(C#C)CCCCC1',
#  '[4*][NH2+][4*],[3*]CC#C,[3*][C@@H]1CCc2ccccc21',
#  '[12*]c1cnc2nc(N)nc(N)c2n1,[3*][C@@H](CCC(=O)[O-])C(=O)[O-],[1*]C([1*])=O,[4*]N[4*],[6*]CC([6*])CC#C,[14*]c1ccc([14*])cc1',
#  'C#N',
#  'N#C[Fe-2](C#N)(C#N)(C#N)(C#N)N=O',
#  '[6*][C@H](O)CO,[11*][C@H]1OC(=O)C(O)=C1[O-]',
#  '[NH3+][C@@H](CS)C(=O)[O-]',
#  '[2*]O[2*],[6*]CO,[3*][C@@H]1O[C@H]([11*])[C@H](O)[C@H](O)[C@H]1O,[3*][C@@H]1[C@@H]([11*])O[C@]([11*])(O)[C@H]1O',
#  '[3*][C@@H]1[C@@H]([3*])O[C@@]([3*])([11*])[C@H]1[3*],[2*]O[2*],[3*]C[6*],[2*]OS(=O)(=O)O[Al](O)O,[3*][C@@H]1[C@@H]([3*])[C@H]([3*])O[C@H]([11*])[C@H]1[3*]',
#  '[6*]CO,[11*][C@H]1O[C@H](O)[C@H](F)[C@@H](O)[C@@H]1O',
#  '[2*]O[2*],[6*]CO,[3*][C@@]1([11*])O[C@H]([11*])[C@@H](O)[C@@H]1O,[3*][C@H]1O[C@H]([11*])[C@@H](O)[C@H](O)[C@H]1O',
#  '[11*][C@H]1OC(=O)[C@H](O)[C@@H](O)[C@@H]1O,[6*]CO',
#  'O=C[C@H](O)[C@@H](O)[C@H](O)CO',
#  'OC[C@@H](O)[C@@H](O)[C@H](O)[C@H](O)CO',
#  'O=C([O-])[C@H](O)[C@@H](O)[C@H](O)[C@H](O)CO',
#  'OC[C@@H](O)[C@@H](O)[C@H](O)[C@@H](O)CO',
#  'NC(N)=[NH2+]',
#  'FC(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)Br',
#  'FC(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)F',
#  'O=C([O-])C(O)C(O)C(=O)[O-]',
#  'O=C([O-])C(S)C(S)C(=O)[O-]',
#  '[2*]OP(=O)([O-])[O-],[3*]CC(Cl)(Cl)Cl',
#  '[NH3+]C(CO)(CO)CO',
#  'OCC(O)CO',
#  '[2*]O[N+](=O)[O-],[3*]CC([3*])C[3*]',
#  'OCC(S)CS',
#  'FC(F)(F)C(F)(F)C(F)(F)F',
#  'FC(F)(F)C(Cl)Br',
#  '[2*]OC(F)F,[3*]C(Cl)C(F)(F)F',
#  '[2*]OC(F)F,[3*]C(F)C(F)(F)F',
#  'FC(F)=C(F)F',
#  '[NH3+]CC(=O)[O-]',
#  'O=C([O-])CC(O)(CC(=O)[O-])C(=O)[O-]',
#  '[3*]C(F)(F)C(F)Cl,[2*]OC(F)F',
#  '[5*]=CC(=O)[O-]',
#  'NC(N)=[NH+]CCC[C@H]([NH3+])C(=O)[O-]',
#  '[4*][NH2+][4*],[4*]N[4*],[3*]CCN,[3*]CC[3*]',
#  '[NH3+]CCC(O)(P(=O)([O-])[O-])P(=O)([O-])[O-]',
#  '[4*][NH2+][4*],[3*]CC[3*],[9*]SP(=O)([O-])[O-],[3*]CCC[NH3+]',
#  '[NH3+]CCCC([NH3+])(C(=O)[O-])C(F)F',
#  '[NH3+]CCCC(O)(P(=O)([O-])[O-])P(=O)([O-])[O-]',
#  'O=C([O-])CCC(=O)[O-]',
#  '[NH3+]CC(=O)CCC(=O)[O-]',
#  'O=C([O-])CCCO',
#  'NC(=O)CC[C@H]([NH3+])C(=O)[O-]',
#  '[1*]C(=O)[C@@H]([3*])C[3*],[9*]SS[9*],[3*]CC(=O)[O-],[4*]N[4*],[1*]C(=O)CC[C@H]([NH3+])C(=O)[O-]',
#  '[NH3+]CCCCCC(=O)[O-]',
#  'O=C([O-])CCCCCCCC(=O)[O-]',
#  '[4*][NH+]([4*])[4*],[4*]N([4*])[4*],[3*]CC(=O)[O-],[3*]CC[3*]',
#  '[2*]O[2*],[3*]CC#CI,[14*]c1cc(Cl)c(Cl)cc1Cl',
#  '[1*]C(=O)C[C@H]([NH3+])C[6*],[6*]C(F)(F)F,[14*]c1cc(F)c(F)cc1F,[4*]N1CCn2c([12*])nnc2C1',
#  '[6*][C@@H]1CS[C@H]([11*])O1,[6*]CO,[7*]n1cc(F)c(N)nc1=O',
#  'O=c1[nH]cc(F)c(=O)[nH]1',
#  '[14*]c1c[nH]c(=O)[nH]c1=O,[3*]CCCl,[4*]N([4*])[4*]',
#  '[7*]n1cc([14*])c(=O)[nH]c1=O,[6*]CO,[6*][C@H]1C[C@H](O)[C@@H]([11*])O1,[6*]C(F)(F)F',
#  '[6*]CO,[6*][C@H]1C[C@H](O)[C@@H]([11*])O1,[7*]n1cc(F)c(=O)[nH]c1=O',
#  '[6*]CO,[6*][C@H]1C[C@H](O)[C@@H]([11*])O1,[7*]n1cc(I)c(=O)[nH]c1=O',
#  'O=c1[nH]cc(F)c(=O)[nH]1',
#  '[4*]NC1=[NH+]CCN1,[14*]c1c(Cl)cc(N)cc1Cl',
#  '[2*]O[2*],[14*]c1cc(I)c([14*])c(I)c1,[14*]c1cc(I)c([O-])c(I)c1,[6*]C[C@H]([NH3+])C(=O)[O-]',
#  '[2*]O[2*],[6*]C[C@@H]([NH3+])C(=O)[O-],[14*]c1cc(I)c([14*])c(I)c1,[14*]c1cc(I)c([O-])c(I)c1',
#  '[1*]C(=O)C(=O)[O-],[14*]c1cc(C#N)cc([14*])c1Cl,[4*]N[4*]',
#  '[2*]O[2*],[14*]c1cc([14*])c(O)c(O)c1,[3*]C[6*],[1*]C([1*])=O,[14*]c1cc(O)c(O)c(O)c1,[3*][C@@H]1[C@@H]([3*])[C@H]([3*])O[C@H]([11*])[C@H]1[3*]',
#  'NS(=O)(=O)c1cc(Cl)c(Cl)c(S(N)(=O)=O)c1',
#  '[3*][C@@H](CCC(=O)[O-])C(=O)[O-],[1*]C([1*])=O,[11*]C1CNc2[nH]c(N)nc(=O)c2N1C=O,[4*]N[4*],[3*]C[6*],[Ca+2],[14*]c1ccc([14*])cc1',
#  '[3*][C@@H](CCC(=O)O)C(=O)O,[1*]C([1*])=O,[11*]C1CNc2[nH]c(N)nc(=O)c2N1C=O,[4*]N[4*],[3*]C[6*],[14*]c1ccc([14*])cc1',
#  '[12*]c1csc([NH+]=C(N)N)n1,[3*]CCC(N)=NS(N)(=O)=O,[3*]C[6*],[9*]S[9*]',
#  '[1*]C(=O)C(=[5*])c1csc(N)n1,[5*]=CCC(=O)[O-],[4*]N[4*],[3*][C@@H]1C(=O)N2C(C(=O)[O-])=CCS[C@H]12',
#  '[6*]CCl,[11*]C1CO1',
#  'Oc1ncnc2[nH]ncc12',
#  'O=C1OC2(c3cc([131I])c([O-])c([131I])c3Oc3c2cc([131I])c([O-])c3[131I])c2c(Cl)c(Cl)c(Cl)c(Cl)c21',
#  '[1*]C(=O)[O-],[7*]n1cc([14*])c(=O)c2cc(F)c([14*])c(Cl)c21,[4*]N1CCCC[C@@H]([NH3+])C1,[6*]C1CC1',
#  '[6*]C(Cl)Cl,[11*]C1Nc2cc(Cl)c(S(N)(=O)=O)cc2S(=O)(=O)N1',
#  '[6*]C1CC2C=CC1C2,[11*]C1Nc2cc(Cl)c(S(N)(=O)=O)cc2S(=O)(=O)N1',
#  'NS(=O)(=O)c1cc2c(cc1Cl)NCNS2(=O)=O',
#  '[7*]n1cc([14*])c(=O)c2cc(F)c([14*])cc21,[1*]C(=O)[O-],[4*]N1CC[NH2+]CC1,[6*]C1CC1',
#  '[NH3+]C12CC3CC(CC(C3)C1)C2',
#  'C1=C/C(=C2\\N=c3cnc4c(c3=N2)COCC4)NO1',
#  '[4*]NC=C([11*])[11*],[1*]C(=O)C[C@@H]([NH3+])CCC[NH3+],[8*]N[8*],[6*]C([11*])[11*],[6*]CO,[1*]C([1*])=O,[6*][C@@H]1CC[NH+]=C(N)N1,[6*]C[C@H]([13*])[NH3+],[3*]C[6*],[4*]N[4*],[1*]C(N)=O',
#  'Nc1cc[nH+]cc1',
#  '[12*]c1cc[nH]n1,[6*]CC[NH3+]',
#  '[14*]c1cccc([14*])c1N,[6*]CC(=O)[O-],[14*]c1ccc(Br)cc1,[1*]C([1*])=O',
#  '[14*]c1c(Cl)cccc1Cl,[6*]CC(=O)[NH+]=C(N)N',
#  '[14*]c1cccc(Cl)c1Cl,[12*]c1nnc(N)nc1N',
#  '[4*]N1CC[NH+]([4*])CC1,[3*]CCCC[3*],[2*]O[2*],[14*]c1cccc(Cl)c1Cl,[14*]c1ccc2c(c1)NC(=O)CC2',
#  '[4*]NC1=[NH+]CCN1,[14*]c1c(Cl)cccc1Cl',
#  '[14*]c1ccc(Cl)cc1,[3*]C(C[6*])CC[6*],[7*]n1ccnc1,[14*]c1c(Cl)cccc1Cl,[9*]S[9*]',
#  '[6*]C[6*],[14*]c1c(F)cccc1F,[7*]n1cc([12*])nn1,[1*]C(N)=O',
#  'O=C1CN2Cc3c(ccc(Cl)c3Cl)[NH+]=C2N1',
#  '[4*]NC1=[NH+]CCN1,[14*]c1ccc2nccnc2c1Br',
#  '[14*]c1c(Cl)ccc2nsnc12,[4*]NC1=[NH+]CCN1',
#  '[14*]c1cc(/N=N/c2ccc(O)c([14*])c2)ccc1O,[1*]C(=O)[O-]',
#  '[6*][C@@H](O)C[NH3+],[14*]c1ccc(O)c(O)c1',
#  '[1*]C([1*])=O,[14*]c1ccc([N+](=O)[O-])cc1Cl,[4*]N[4*],[14*]c1cc(Cl)ccc1O',
#  '[14*]c1ccc([14*])c([N+](=O)[O-])c1,[13*][C-]1C(=O)CCCC1=O,[1*]C([1*])=O,[6*]C(F)(F)F',
#  '[13*]C1CC1,[2*]O[2*],[2*]OC(F)F,[1*]C([1*])=O,[3*]C[6*],[4*]N[4*],[14*]c1c(Cl)cncc1Cl,[14*]c1ccc([14*])c([14*])c1',
#  '[1*]C(=O)[O-],[14*]c1ccc(F)cc1F,[14*]c1ccc(O)c([14*])c1',
#  '[6*]C[C@H]([NH3+])C(=O)[O-],[14*]c1ccc(O)c(O)c1',
#  '[14*]c1ccc(O)c(O)c1,[6*]CC[NH3+]',
#  '[2*]O[2*],[7*]n1ccnc1,[14*]c1ccsc1Cl,[3*]C([6*])C[6*],[3*]C[6*],[14*]c1ccc(Cl)cc1Cl',
#  '[10*]S(=O)(=O)c1ccc(Br)s1,[1*]C([1*])=O,[14*]c1ccc(Cl)cc1Cl,[4*]N[4*]',
#  '[7*]n1ccnc1,[2*]O/N=C(/C[6*])c1ccc(Cl)cc1Cl,[14*]c1ccc(Cl)cc1Cl,[3*]C[6*]',
#  '[2*]O[2*],[7*]n1ccnc1,[3*]C([6*])C[6*],[3*]C[6*],[14*]c1ccc(Cl)cc1Cl',
#  '[2*]O[2*],[14*]c1ccc(Cl)cc1Cl,[14*]c1ccc(Cl)cc1O',
#  '[6*]CC([6*])(O)C[6*],[7*]n1cncn1,[14*]c1ccc(F)cc1F',
#  '[7*]n1cc([14*])c(=O)c2cc(F)c([12*])nc21,[4*]N1C[C@@H]2[C@@H]([NH3+])[C@@H]2C1,[1*]C(=O)[O-],[14*]c1ccc(F)cc1F',
#  '[14*]c1cc(N)ccc1O,[1*]C(=O)[O-]',
#  '[14*]c1ccc(N)cc1O,[1*]C(=O)[O-]',
#  '[14*]c1ccc(O)c(I)c1,[14*]c1cc(I)c([14*])c(I)c1,[6*]C[C@H]([NH3+])C(=O)[O-],[2*]O[2*]',
#  '[2*]O[2*],[3*]CC(F)(F)F,[1*]C([1*])=O,[3*]C[6*],[4*]N[4*],[14*]c1ccc([14*])c([14*])c1,[11*]C1CCCC[NH2+]1',
#  '[1*]C(=O)O,N,[13*]C1([13*])CCC1,[Pt]',
#  '[3*]CC[3*],[4*][NH2+][4*],[14*]c1ccc([14*])c2c1C(=O)c1c([O-])ccc([O-])c1C2=O,[4*]N[4*],[3*]CCO',
#  '[14*]c1ccc([14*])c2c1C(=O)c1c(O)ccc(O)c1C2=O,[3*]CCO,[4*]N[4*],[3*]CC[3*]',
#  '[4*][NH+]1CC[C@]23c4c5ccc(O)c4O[C@H]2C(=O)CC[C@@]3(O)[C@H]1C5,[13*]C1CC1,[3*]C[6*]',
#  '[13*]C1CCC1,[3*]C[6*],[4*][NH+]1CC[C@]23c4c5ccc(O)c4O[C@H]2[C@@H](O)CC[C@@]3(O)[C@H]1C5',
#  '[14*]c1cccc([131I])c1,[6*]C[NH+]=C(N)N',
#  '[14*]c1ccc(F)cc1,[6*][C@@H]1[C@@H]([13*])C(=O)N1[8*],[6*]CC[C@H]([6*])O,[14*]c1ccc(O)cc1',
#  '[14*]c1ccc2c(c1)OCO2,[2*]O[2*],[3*]C[6*],[14*]c1ccc(F)cc1,[6*][C@@H]1CC[NH2+]C[C@@H]1[13*]',
#  '[1*]C(=O)[C-](Cl)Cl,[3*][C@H](CO)[C@@H]([6*])O,[14*]c1ccc([N+](=O)[O-])cc1,[4*]N[4*]',
#  '[14*]c1ccc([N+](=O)[O-])cc1,[2*]O[2*],[3*]C[C@@H]([3*])[C@@H]([6*])O,[1*]C(=O)CCC(=O)[O-],[1*]C(=O)[C-](Cl)Cl,[4*]N[4*]',
#  '[6*]C([6*])[6*],[7*]n1cncn1,[14*]c1ccc(C#N)cc1',
#  '[14*]c1ccc(Cl)cc1,[6*]C(C[NH3+])CC(=O)[O-]',
#  '[14*]c1ccc(F)cc1,[14*]c1ccc(Cl)cc1,[1*]C(=O)CCC[3*],[4*][NH+]1CCC([6*])(O)CC1',
#  '[11*][C@H]1CNc2[nH]c(N)nc(=O)c2N1C=O,[3*][C@@H](CCC(=O)[O-])C(=O)[O-],[3*]C[6*],[1*]C([1*])=O,[4*]N[4*],[14*]c1ccc([14*])cc1',
#  '[3*][C@@H](CCC(=O)[O-])C(=O)[O-],[3*]C[6*],[1*]C([1*])=O,[4*]N[4*],[11*]C1CNc2[nH]c(N)nc(=O)c2N1C=O,[14*]c1ccc([14*])cc1',
#  '[3*][C@@H](CCC(=O)[O-])C(=O)[O-],[12*]c1cnc2[nH]c(N)nc(=O)c2n1,[3*]C[6*],[1*]C([1*])=O,[4*]N[4*],[14*]c1ccc([14*])cc1',
#  '[14*]c1ccc(N)cc1,[1*]C([1*])=O,[3*]CC(=O)[O-],[4*]N[4*]',
#  '[14*]c1ccc(N/N=C2/C=CC(=O)C(C(=O)[O-])=C2)cc1,[3*]CCC(=O)[O-],[1*]C([1*])=O,[4*]N[4*]',
#  '[12*]c1sc2cc(O)ccc2c1[14*],[4*][NH+]1CCCCC1,[3*]CC[3*],[2*]O[2*],[14*]c1ccc(O)cc1,[1*]C([1*])=O,[14*]c1ccc([14*])cc1',
#  '[6*]C1C[NH2+]CCc2c1cc(O)c(O)c2Cl,[14*]c1ccc(O)cc1',
#  '[14*]c1ccc([N+](=O)[O-])cc1,[12*]c1ccc(/C=N/N2CC(=O)NC2=O)o1',
#  '[3*]CCCl,[6*]C[C@H]([NH3+])C(=O)[O-],[14*]c1ccc([14*])cc1,[4*]N([4*])[4*]',
#  '[6*]C[C@H]([NH3+])C(=O)[O-],[14*]c1ccc(O)cc1',
#  '[3*]CC[3*],[3*]CCC[3*],[4*][NH+]([4*])[4*],[4*][NH2+][4*],[3*]C[6*],[4*]N[4*],[14*]c1ccc([14*])cc1',
#  '[14*]c1ccc(S(N)(=O)=O)cc1,[6*]C[NH3+]',
#  '[14*]c1c[nH]c2[nH]c(N)nc(=O)c12,[3*][C@@H](CCC(=O)[O-])C(=O)[O-],[1*]C([1*])=O,[4*]N[4*],[6*]CC[6*],[14*]c1ccc([14*])cc1',
#  '[14*]c1c[nH]c2[nH]c(N)nc(=O)c12,[3*][C@@H](CCC(=O)O)C(=O)O,[1*]C([1*])=O,[4*]N[4*],[6*]CC[6*],[14*]c1ccc([14*])cc1',
#  '[6*]CCCC(=O)[O-],[3*]CCCl,[14*]c1ccc([14*])cc1,[4*]N([4*])[4*]',
#  '[3*]C[C@H]([6*])O,[14*]c1ccc(O)cc1,[3*]CCCC[6*],[4*][NH2+][4*],[14*]c1ccc(O)c(O)c1',
#  '[14*]c1ccc(Cl)cc1,[2*]O[2*],[7*]n1ccnc1,[3*]C([6*])C[6*],[3*]C[6*],[14*]c1ccc(Cl)cc1Cl',
#  '[14*]c1ccc(Cl)cc1,[7*]n1ccnc1,[3*]C([6*])C[6*],[3*]C[6*],[14*]c1ccc(Cl)cc1Cl,[9*]S[9*]',
#  'Nc1ccc(S(=O)(=O)c2ccc(N)cc2)cc1',
#  'Nc1ccc(S(N)(=O)=O)cc1',
#  '[8*]N1C[C@H]([11*])OC1=O,[8*]N1CCOCC1=O,[3*]C[6*],[1*]C([1*])=O,[4*]N[4*],[14*]c1ccc([14*])cc1,[12*]c1ccc(Cl)s1',
#  '[4*]NC(=[NH2+])NC(=[NH2+])N[4*],[14*]c1ccc(Cl)cc1,[3*]CCCCCC[3*]',
#  '[4*]NCS(=O)[O-],[14*]c1ccc(S(=O)(=O)c2ccc([14*])cc2)cc1',
#  'Oc1ccc(O)cc1',
#  '[3*]CC(O)C[3*],[14*]c1ccc(Cl)cc1,[1*]C(N)=O,[2*]O[2*]',
#  '[14*]c1ccc(Cl)cc1,[9*]SC(P(=O)([O-])[O-])P(=O)([O-])[O-]',
#  '[14*]c1cccnc1,[1*]C(=O)[O-]',
#  '[14*]c1cccnc1,[1*]C(N)=O',
#  '[14*]c1cccnc1,[6*]CC(O)(P(=O)([O-])[O-])P(=O)([O-])[O-]',
#  '[6*]C1CCC(=O)NC1=O,[8*]N1C(=O)c2cccc(N)c2C1=O',
#  '[6*]C1CCC(=O)NC1=O,[8*]N1C(=O)c2ccccc2C1=O',
#  '[6*]C1CCC(=O)NC1=O,[8*]N1Cc2c(N)cccc2C1=O',
#  '[4*]N1CCN([4*])CC1,[2*]O[2*],[3*]CCCC[3*],[14*]c1cccc(Cl)c1Cl,[14*]c1ccc2c(c1)NC(=O)CC2',
#  '[14*]c1cc(Cl)c(S(N)(=O)=O)cc1[14*],[1*]C(=O)[O-],[3*]C[6*],[4*]N[4*],[12*]c1ccco1',
#  'O=C1CN(/N=C/c2ccc([N+](=O)[O-])o2)C(=O)N1',
#  'O=C1OCCN1/N=C/c1ccc([N+](=O)[O-])o1',
#  'NC(=O)N/N=C/c1ccc([N+](=O)[O-])o1',
#  'O=C1O[Pt]OC(=O)C12CCC2',
#  '[8*]N1Cc2c(N)cccc2C1=O,[6*]C1CCC(=O)NC1=O',
#  '[3*]CC(O)C[3*],[2*]O[2*],[12*]c1cc(=O)c2c([14*])cccc2o1,[1*]C(=O)[O-]',
#  'Oc1c(Cl)cc(Cl)c2cccnc12',
#  'Oc1c(I)cc(Cl)c2cccnc12',
#  '[12*]c1cc([14*])c2cccc([14*])c2n1,[11*]C1CCCC[NH2+]1,[6*]C([6*])O,[6*]C(F)(F)F',
#  '[6*][C@H]1CC[C@H](C2=C([O-])C(=O)c3ccccc3C2=O)CC1,[14*]c1ccc(Cl)cc1',
#  '[4*]N1CC[NH+]([4*])CC1,[12*]c1cc2cc([14*])ccc2o1,[3*]CCCC[6*],[14*]c1c[nH]c2ccc(C#N)cc12,[1*]C(N)=O',
#  'O=C1Nc2ccc(Cl)cc2[C@@](C#CC2CC2)(C(F)(F)F)O1',
#  'O=c1[nH]c2cc(Cl)ccc2o1',
#  '[4*][NH2+][4*],[3*]CC([6*])O,[11*]C1CCc2cc(F)ccc2O1',
#  '[14*]c1ccc2nc(N)sc2c1,[2*]OC(F)(F)F',
#  '[2*]O[2*],[6*]C1CCCCC1,[3*]CCCC[6*],[7*]n1nnnc1[12*],[14*]c1ccc2c(c1)CCC(=O)N2',
#  '[2*]O[2*],[7*]n1ccnc1,[3*]C([6*])C[6*],[3*]C[6*],[14*]c1csc2c(Cl)cccc12,[14*]c1ccc(Cl)cc1Cl',
#  '[5*]=C1CC[NH2+]CC1,[5*]=C1c2ccc(Cl)cc2CCc2cccnc21',
#  '[8*]N1C[C@H]2CCCc3cccc(c32)C1=O,[6*][C@@H]1C[NH+]2CCC1CC2',
#  'Oc1cccc2cccnc12',
#  'N[C@@H]1CCCC[C@H]1[NH3+]',
#  '[14*]c1ccccc1Cl,[6*]C([6*])C(Cl)Cl,[14*]c1ccc(Cl)cc1',
#  '[1*]C(=O)O,[3*]CCC[C@H]([3*])C(=O)O,[14*]c1ccccc1[14*],[1*]C([1*])=O,[3*]C[6*],[4*]N[4*],[12*]c1cnc2nc(N)nc(N)c2n1,[14*]c1ccc([14*])cc1',
#  'O=C1Nc2ccc(Cl)cc2C(c2ccccc2Cl)=NC1O',
#  '[14*]c1ccccc1O,[7*]n1nc([12*])nc1[12*],[1*]C(=O)[O-],[14*]c1ccc([14*])cc1',
#  'O=C1CN=C(c2ccccc2Cl)c2cc([N+](=O)[O-])ccc2N1',
#  '[3*]CC(F)(F)F,[4*]N1C(=S)CN=C(c2ccccc2F)c2cc(Cl)ccc21',
#  '[4*][NH+]1CCc2sccc2C1,[14*]c1ccccc1Cl,[3*]C[6*]',
#  '[14*]c1c(Cl)cccc1Cl,[6*]CC(=O)[O-],[4*]N[4*],[14*]c1ccccc1[14*]',
#  '[3*]CC1=C(C(=O)[O-])N2C(=O)[C@@H]([3*])[C@H]2SC1,[14*]c1ccccc1[14*],[6*]CC(=O)[O-],[6*]C[NH3+],[7*]n1nnnc1[12*],[4*]N[4*],[9*]S[9*],[1*]C(=O)C[6*]',
#  '[6*]CC(=O)[O-],[6*]C[NH3+],[13*]C1([13*])CCCCC1',
#  'Nc1ccc(/N=N/c2ccccc2)c(N)n1',
#  '[3*]CC1=C(C(=O)[O-])N2C(=O)[C@@H]([3*])[C@H]2SC1,[6*]CS(=O)(=O)[O-],[14*]c1ccccc1,[7*]n1nnnc1[12*],[1*]C(=O)[C@@H]([6*])O,[4*]N[4*],[9*]S[9*]',
#  '[3*][C@@H]1C(=O)N2C(C(=O)[O-])=C(Cl)CC[C@H]12,[14*]c1ccccc1,[1*]C(=O)[C@@H]([6*])[NH3+],[4*]N[4*]',
#  '[14*]c1ccc(Cl)cc1,[3*]CC[3*],[4*]N1CC[NH+]([4*])CC1,[2*]O[2*],[14*]c1ccccc1,[3*]CC(=O)[O-],[3*]C([6*])[6*]',
#  '[3*][C@H]1C[NH+]2CCC1CC2,[2*]O[2*],[14*]c1ccccc1,[1*]C([1*])=O,[4*]N1CCc2ccccc2[C@@H]1[6*]',
#  '[14*]c1ccccc1,[6*][C@H]1CN2CCSC2=[NH+]1',
#  '[14*]c1ccc(Cl)cc1,[3*]CC[3*],[4*]N1CC[NH+]([4*])CC1,[2*]O[2*],[14*]c1ccccc1,[3*]CC(=O)[O-],[3*]C([6*])[6*]',
#  '[14*]c1ccc(Cl)cc1,[3*]CC[3*],[4*]N1CC[NH+]([4*])CC1,[2*]O[2*],[14*]c1ccccc1,[3*]CCO,[3*]C([6*])[6*]',
#  '[4*][NH+]1CC[C@@H]([13*])C1,[6*]C([6*])([6*])C(N)=O,[3*]CC[6*],[14*]c1ccccc1,[14*]c1ccc2c(c1)CCO2',
#  '[1*]C(=O)C([6*])([6*])O,[14*]c1ccccc1,[3*]C1CC2CCC(C1)[N+]21CCCC1,[2*]O[2*]',
#  '[7*]n1ccnc1,[14*]c1ccccc1Cl,[14*]c1ccccc1,[6*]C([6*])([6*])[6*]',
#  '[14*]c1ccccc1,[6*]C([6*])[S@](=O)CC(N)=O',
#  '[14*]c1ccccc1,[6*]C([6*])S(=O)CC(N)=O',
#  '[14*]c1ccccc1,[4*][NH+]1CCCC1,[13*]C1CCCCC1,[3*]CCC([6*])([6*])O',
#  '[14*]c1ccccc1,[4*][NH+]1CCCCC1,[3*]CCC([6*])([6*])O,[13*]C1CC2C=CC1C2',
#  '[13*]C1CCCC1,[14*]c1ccccc1,[4*][NH+]1CCCCC1,[3*]CCC([6*])([6*])O',
#  '[14*]c1ccccc1,[4*][NH+]1CCCCC1,[13*]C1CCCCC1,[3*]CCC([6*])([6*])O',
#  '[14*]c1ccccc1,[4*][NH+]1CCCCC1,[3*]CCCC([6*])([6*])O',
#  '[3*]CC([6*])C[3*],[2*]O[2*],[14*]c1ccccc1,[1*]C(N)=O',
#  '[14*]c1ccccc1,[1*]C(=O)[O-]',
#  '[14*]c1ccccc1,[12*]c1ccc2n1CCC2C(=O)[O-],[1*]C([1*])=O',
#  '[14*]c1cccc([14*])c1N,[6*]CC(N)=O,[14*]c1ccccc1,[1*]C([1*])=O',
#  '[14*]c1ccc(O)cc1,[14*]c1ccccc1,[1*]C(=O)[O-],[1*]C([1*])=O,[1*]C(=O)C([3*])C[6*],[4*]N[4*],[14*]c1ccc([14*])cc1',
#  '[14*]c1ccccc1,[1*]C([1*])=O,[3*]CC(=O)[O-],[4*]N[4*]',
#  '[14*]c1ccccc1,[1*]C([1*])=O,[2*]OO[2*]',
#  '[6*]C1([6*])NC(=O)N([8*])C1=O,[14*]c1ccccc1,[6*]COP(=O)([O-])[O-]',
#  '[14*]c1ccccc1,[6*]C1([6*])NC(=O)NC1=O',
#  '[14*]c1ccccc1,[1*]C(=O)[O-],[3*]CCC([6*])([6*])C#N,[4*][NH+]1CCC([6*])([13*])CC1',
#  '[14*]c1ccccc1,[12*]c1nc2c(N)nc(N)nc2nc1N',
#  '[14*]c1ccccc1,[6*]C1OC(N)=[NH+]C1=O',
#  '[14*]c1ccccc1,[6*]C1C(=O)c2ccccc2C1=O',
#  '[14*]c1ccccc1,[12*]c1nc([12*])c([12*])o1,[6*]CCC(=O)[O-]',
#  '[14*]c1ccccc1,[6*]C1C[C@H]1[NH3+]',
#  '[1*]C(=O)[O-],[11*]C1N=C(c2ccccc2)c2cc(Cl)ccc2NC1=O',
#  'O=C1Nc2ccc(Cl)cc2C(c2ccccc2)=NC1O',
#  '[8*]N1C(=O)CN=C(c2ccccc2)c2cc(Cl)ccc21,[6*]CC(F)(F)F',
#  '[6*]C[6*],[13*]C1CC1,[8*]N1C(=O)CN=C(c2ccccc2)c2cc(Cl)ccc21',
#  'Clc1ccc2c(c1)C(c1ccccc1)=NCc1nncn1-2',
#  '[6*]C[6*],[3*]C[C@H]([6*])[11*],[3*]CC(N)=O,[6*]CC(N)=O,[8*]N[8*],[1*]C(=O)[C@H]([3*])CCC[3*],[14*]c1ccc(O)cc1,[6*]C([11*])[11*],[14*]c1ccccc1,[6*]CCC(N)=O,[1*]C([1*])=O,[4*]NC(N)=[NH2+],[9*]SS[9*],[3*]CC[13*],[4*]N[4*],[4*]N1CCC[C@@H]1[11*]',
#  '[14*]c1ccccc1,[6*]CC(=O)[O-]',
#  '[14*]c1ccccc1,[4*]N[4*],[1*]C(=O)C[6*],[1*]C(N)=O',
#  '[6*]CC1=[NH+]CCN1,[14*]c1ccccc1',
#  '[6*]C[6*],[1*]C(=O)C([3*])CCC[NH+]=C(N)N,[4*]N1CCCC1[11*],[6*]CC(N)=O,[8*]N[8*],[14*]c1ccc(O)cc1,[6*]C([11*])[11*],[14*]c1ccccc1,[6*]CCC(N)=O,[1*]C([1*])=O,[9*]SS[9*],[4*]N[4*],[3*]CC(N)=O,[3*]CC([13*])[NH3+],[3*]CC([6*])[11*]',
#  '[6*]C[6*],[4*]N1CCCC1[11*],[6*]CC(N)=O,[8*]N[8*],[14*]c1ccc(O)cc1,[6*]C([11*])[11*],[1*]C(=O)C([3*])CCCC[NH3+],[14*]c1ccccc1,[6*]CCC(N)=O,[1*]C([1*])=O,[9*]SS[9*],[4*]N[4*],[3*]CC(N)=O,[3*]CC([13*])[NH3+],[3*]CC([6*])[11*]',
#  '[6*]C[6*],[14*]c1ccccc1,[6*]C(F)(F)F,[11*]C1Nc2cc([14*])c(S(N)(=O)=O)cc2S(=O)(=O)N1',
#  '[4*]N1CCC[C@@H]1[11*],[1*]C(=O)[C@@H]([3*])CCCC[NH3+],[4*][NH2+][4*],[14*]c1ccccc1,[1*]C(=O)[O-],[3*][C@@H](CC[6*])C(=O)[O-]',
#  '[6*]CCCC(=O)[O-],[14*]c1ccccc1',
#  '[3*]CC([6*])O,[14*]c1ccc(O)c([14*])c1,[2*]O[2*],[3*]CCCCCC[3*],[3*]CCCC[6*],[14*]c1ccccc1,[4*][NH2+][4*],[6*]CO',
#  '[14*]c1ccccc1,[6*]CCNN',
#  '[3*]CC1=[NH+]CCN1,[14*]c1ccccc1,[3*]C[6*],[4*]N([4*])[4*]',
#  '[6*]C[6*],[14*]c1ccccc1,[8*]N1C(=O)N([8*])C2C1C[S+]1CCCC21',
#  '[2*]O[2*],[14*]c1ccccc1,[1*]C([1*])=O,[3*]C[6*]',
#  '[2*]O[2*],[14*]c1ccccc1,[3*]C[6*],[14*]c1ccc(O)cc1',
#  '[3*]CC([3*])C(=O)[O-],[3*]CC[3*],[2*]O[2*],[4*][NH+]([4*])[4*],[14*]c1ccccc1,[3*]C[6*],[3*]CC(=O)[O-],[4*]N([4*])[4*]',
#  '[14*]c1ccccc1,[3*]C[6*],[9*]S[9*],[3*]CC1=NS(=O)(=O)c2cc(S(N)(=O)=O)c(Cl)cc2N1',
#  '[10*]S(=O)(=O)c1ccc(N)cc1,[14*]c1ccccc1,[7*]n1nccc1[12*],[4*][N-][4*]',
#  '[14*]c1ccccc1,[4*]N[4*],[1*]C(=O)CCCCCCC(=O)NO',
#  '[1*]C(=O)N(CCCl)N=O,[3*]C1CCCCC1,[4*]N[4*]',
#  '[5*]=CC(=O)NO,[5*]=Cc1cccc(S([10*])(=O)=O)c1,[14*]c1ccccc1,[4*]N[4*]',
#  '[2*]O[2*],[14*]c1ccccc1,[1*]C([1*])=O,[14*]c1ccc(N)cc1O',
#  '[6*]C[NH+]=C(N)N,[11*]C1COC2(CCCCC2)O1',
#  'Clc1ccc2c(c1)C(N1CC[NH2+]CC1)=[NH+]c1ccccc1O2',
#  '[3*]CCCC([6*])[6*],[7*]n1c(=O)[nH]c2ccccc21,[14*]c1ccc(F)cc1,[4*][NH+]1CCC([6*])CC1',
#  '[14*]c1ccc(F)cc1,[1*]C(=O)CCC[3*],[4*][NH+]1CC=C(n2c(=O)[nH]c3ccccc32)CC1',
#  '[2*]O[2*],[3*]CC[3*],[3*]CCO,[4*][NH+]1CCN(C2=[NH+]c3ccccc3Sc3ccccc32)CC1',
#  '[14*]c1ccc(F)cc1,[6*]C1CC1,[5*]=C[C@@H](O)C[C@@H](O)CC(=O)[O-],[5*]=Cc1c([12*])nc2ccccc2c1[14*]',
#  '[6*]C[6*],[14*]c1c([O-])c2ccccc2oc1=O',
#  'Nc1c2c([nH+]c3ccccc13)CCCC2',
#  '[3*]C1CC2CC3C[C@H](C1)[NH+]2CC3=O,[2*]O[2*],[1*]C([1*])=O,[14*]c1c[nH]c2ccccc12',
#  '[14*]c1ccc(Cl)cc1,[6*]C[6*],[12*]c1nnc([12*])c2ccccc12,[14*]c1ccncc1,[4*]N[4*]',
#  '[6*]CS(N)(=O)=O,[12*]c1noc2ccccc12',
#  '[6*]C[6*],[4*]N1CC[NH+]([4*])CC1,[13*][C@@H]1CCCC[C@@H]1[13*],[12*]c1nsc2ccccc12,[8*]N1C(=O)[C@@H]2[C@H]3CC[C@H](C3)[C@@H]2C1=O,[3*]C[6*]',
#  '[4*]N1CC[NH+]([4*])CC1,[3*]CC[6*],[14*]c1cc2c(cc1Cl)NC(=O)C2,[12*]c1nsc2ccccc12',
#  '[6*]C1CCC(=O)NC1=O,[8*]N1C(=O)c2ccccc2C1=O',
#  '[6*]C1(O)NC(=O)c2ccccc21,[14*]c1ccc(Cl)c(S(N)(=O)=O)c1',
#  'O=C1O[Bi](O)Oc2ccccc21',
#  'O=C1OC2(c3ccc(O)cc3Oc3cc(O)ccc32)c2ccccc21',
#  '[14*]c1ccc(Cl)cc1,[6*]C1(O)c2ccccc2C2=[NH+]CCN21',
#  '[1*]C(=O)CCS,[4*]N1CCc2c([nH]c3ccccc23)C1',
#  '[6*]C[6*],[1*]C(=O)[O-],[14*]c1cc2ccccc2c([14*])c1O',
#  '[1*]C(=O)C[3*],[12*]c1cccs1,[1*]C(=O)C([3*])CCC[NH+]=C(N)N,[4*]N1CCCC1[11*],[4*]N1C([11*])C[C@@H]2CCCC[C@@H]21,[4*]N1Cc2ccccc2CC1[11*],[1*]C(=O)[C@@H]([3*])C[6*],[1*]C([1*])=O,[4*]N[4*],[1*]C(=O)[C@@H]([3*])CO,[4*]N1C[C@H](O)CC1[11*],[3*][C@@H](CCC[NH+]=C(N)N)C(=O)[O-],[1*]C(=O)[C@H]([NH3+])CCC[NH+]=C(N)N',
#  '[4*]N1c2ccccc2CC(=O)c2ccccc21,[1*]C(N)=O',
#  'NC1=[NH+]CC2c3ccccc3Cc3ccccc3N12',
#  '[1*]C(N)=O,[4*]N1c2ccccc2C=Cc2ccccc21',
#  'c1ccc2c(c1)CCCC2C1=[NH+]CCN1',
#  '[6*]CC1=[NH+]CCN1,[14*]c1cccc2ccccc12',
#  '[13*]C1CCCCC1,[1*]C([1*])=O,[4*]N1CC(=O)N2CCc3ccccc3C2C1',
#  'NNc1nncc2ccccc12',
#  '[4*]N1CC[NH+]([4*])CC1,[3*]CCC[3*],[3*]CCO,[4*]N1c2ccccc2Sc2ccc([14*])cc21,[6*]C(F)(F)F',
#  '[4*]N1CC[NH+]([4*])CC1,[4*]N1c2ccccc2Sc2ccc(Cl)cc21,[3*]CCO,[3*]CCC[3*]',
#  '[4*]N1CCCCCCC1,[3*]CC[NH+]=C(N)N',
#  '[O-]n1ccccc1=S',
#  '[4*]N1CCCCC1,[1*]C([1*])=O,[14*]c1ccc2nonc2c1',
#  '[4*]N1CC[NH+]([4*])CC1,[14*]c1cccc(Cl)c1,[3*]CCC[6*],[7*]n1nc2ccccn2c1=O',
#  '[14*]c1ccc(F)c(F)c1[14*],[14*]c1ccc(I)cc1F,[1*]C([1*])=O,[4*]N1CC([6*])(O)C1,[4*]N[4*],[11*][C@@H]1CCCCN1',
#  '[14*]c1ccc(Cl)cc1,[12*]c1ccccn1,[2*]O[2*],[3*]CCCC(=O)[O-],[3*]C([6*])[6*],[3*]C1CC[NH+]([4*])CC1',
#  '[10*]S(=O)(=O)c1ccc(/N=N/c2ccc(O)c([14*])c2)cc1,[1*]C(=O)[O-],[12*]c1ccccn1,[4*][N-][4*]',
#  '[10*]S(=O)(=O)c1ccc(N)cc1,[12*]c1ccccn1,[4*][N-][4*]',
#  '[6*][C@@H]1CS[C@H]([11*])O1,[6*]CO,[7*]n1ccc(N)nc1=O',
#  '[6*][C@@H]1O[C@H]([11*])[C@@H](O)[C@@H]1O,[6*]CO,[7*]n1ccc(N)nc1=O',
#  '[6*][C@@H]1O[C@H]([11*])[C@@H](O)C1(F)F,[6*]CO,[7*]n1ccc(N)nc1=O',
#  '[6*][C@@H]1O[C@H]([11*])[C@@H](O)C1(F)F,[6*]CO,[7*]n1ccc(N)nc1=O,Cl',
#  '[6*]CO,[7*]n1ccc(N)nc1=O,[6*][C@H]1CC[C@@H]([11*])O1',
#  '[2*]OCP(=O)([O-])[O-],[3*][C@@H](C[6*])CO,[7*]n1ccc(N)nc1=O',
#  '[3*]CC[3*],[4*][NH+]([4*])[4*],[3*]C(CO)C(O)CO,[3*]CC(=O)[O-],[4*]N([4*])[4*]',
#  '[4*]N1CCN([4*])CC1,[1*]C(=O)CCBr',
#  '[4*]N1CCN([4*])CC1,[1*]C([1*])=O,[3*]C[6*],[4*]N[4*],[14*]c1ccc2c(c1)OC(F)(F)O2,[14*]c1cnccc1Cl',
#  '[7*]n1ccnc1,[6*]CC(O)(P(=O)([O-])[O-])P(=O)([O-])[O-]',
#  'O=P1(NCCCl)OCCCN1CCCl',
#  'S=P(N1CC1)(N1CC1)N1CC1',
#  '[1*]C(N)=O,[12*]c1cnccn1',
#  '[10*]S(=O)(=O)c1ccc(N)cc1,[12*]c1ncccn1,[4*][N-][4*]',
#  '[4*]N1CC[NH+]([4*])CC1,[3*]CCCC[6*],[12*]c1ncccn1,[8*]N1C(=O)CC2(CCCC2)CC1=O',
#  'c1cnc2cc3c(cc2n1)[C@@H]1C[NH2+]C[C@H]3C1',
#  'C1C[NH2+]CCN1',
#  '[14*]c1ccncc1,[1*]C(=O)NN',
#  '[14*]c1ccncc1,[14*]c1c[nH]c(=O)c(N)c1',
#  'O=P1(N(CCCl)CCCl)NCCCO1',
#  'O=C1CCO1',
#  '[7*]n1cnc2c(N)ncnc21,[6*]CO,[6*][C@@H]1O[C@H]([11*])[C@@H](O)[C@H]1O',
#  '[7*]n1cnc2c(N)ncnc21,[6*]CO,[6*][C@@H]1O[C@H]([11*])[C@@H](O)[C@@H]1O',
#  '[6*]CO,[7*]n1cnc(N)nc1=O,[6*][C@@H]1O[C@H]([11*])[C@@H](O)[C@H]1O',
#  '[6*]CO,[7*]n1cnc(N)nc1=O,[6*][C@H]1C[C@H](O)[C@@H]([11*])O1',
#  '[7*]n1cnc([12*])n1,[6*][C@@H]1O[C@H]([11*])[C@@H](O)[C@H]1O,[1*]C(N)=O,[6*]CO',
#  'Nc1nc(=S)c2[nH]cnc2[nH]1',
#  'S=c1nc[nH]c2nc[nH]c12',
#  '[14*]c1ccc(Cl)cc1,[1*]C(=O)[C@@H]([3*])CCC[3*],[14*]c1ccc2ccccc2c1,[14*]c1cccnc1,[1*]C(=O)[C@H]([3*])CCC[3*],[3*][C@H](C)C(N)=O,[14*]c1ccc(O)cc1,[1*]C(=O)[C@@H]([3*])C[6*],[1*]C(C)=O,[1*]C([1*])=O,[4*]NC(N)=[NH2+],[4*]N[4*],[4*]N1CCC[C@H]1[11*],[1*]C(=O)[C@@H]([3*])CC(C)C,[1*]C(=O)[C@@H]([3*])CO,[1*]C(=O)[C@H]([3*])C[6*],[1*]C(N)=O',
#  '[14*]c1cnc(N)c([14*])c1,[7*]n1cc([14*])cn1,[14*]c1c(Cl)ccc(F)c1Cl,[2*]O[2*],[6*]C1CC[NH2+]CC1,[3*][C@H]([6*])C',
#  '[12*]c1n[nH]c(=O)[nH]1,[2*]O[2*],[3*][C@H]([6*])C,[14*]c1cc([14*])cc([14*])c1,[3*]C[6*],[3*][C@H]1OCC[NH+]([4*])[C@H]1[6*],[14*]c1ccc(F)cc1,[6*]C(F)(F)F',
#  '[3*][C@H]([6*])C,[4*][NH2+][4*],[14*]c1cccc([14*])c1,[3*]CCC[6*],[14*]c1cccc2ccccc12,[6*]C(F)(F)F',
#  '[3*]CCCO,[4*]N1CCc2cc([14*])cc([14*])c21,[3*][C@H](C)C[6*],[3*]CC[3*],[2*]O[2*],[3*]CC(F)(F)F,[14*]c1ccccc1[14*],[4*][NH2+][4*],[1*]C(N)=O',
#  '[14*]c1ccc(O)c(O)c1,[6*]C[C@@H](C)[C@@H](C)C[6*]',
#  '[3*][C@H](C)C[6*],[14*]c1ccc(O)c([14*])c1,[3*]C[C@H]([6*])O,[2*]OC,[4*][NH2+][4*],[4*]NC=O,[14*]c1ccc([14*])cc1',
#  '[14*]c1ccccc1,[3*]CC#C,[4*][NH+]([4*])C,[3*][C@H](C)C[6*]',
#  '[6*][C@H](C)CCC(=O)[O-],[13*][C@H]1CC[C@H]2[C@@H]3[C@H](O)C[C@@H]4C[C@H](O)CC[C@]4(C)[C@H]3CC[C@]12C',
#  '[6*][C@H](C)CCC(=O)[O-],[13*][C@H]1CC[C@H]2[C@@H]3[C@@H](O)C[C@@H]4C[C@H](O)CC[C@]4(C)[C@H]3CC[C@]12C',
#  '[5*]=C1C[C@@H](O)C[C@H](O)C1=C,[6*][C@H](C)CCCC(C)(C)O,[5*]=CC=[5*],[5*]=C1CCC[C@]2(C)[C@@H]([13*])CC[C@@H]12',
#  '[5*]=C1C[C@@H](O)CCC1=C,[6*][C@H](C)CCCC(C)(C)O,[5*]=CC=[5*],[5*]=C1CCC[C@]2(C)[C@@H]([13*])CC[C@@H]12',
#  '[6*][C@H](C)CCCC(C)C,[5*]=C1C[C@@H](O)CCC1=C,[5*]=CC=[5*],[5*]=C1CCC[C@]2(C)[C@@H]([13*])CC[C@@H]12',
#  '[2*]OCP(=O)([O-])[O-],[7*]n1cnc2c(N)ncnc21,[3*][C@H](C)C[6*]',
#  '[3*][C@H](C)C[6*],[2*]O[2*],[2*]OCOP(=O)(CO[2*])OCO[2*],[1*]C([1*])=O,[3*]C(C)C,[7*]n1cnc2c(N)ncnc21',
#  '[14*]c1c(F)cc2c(=O)c([14*])cn3c2c1OC[C@@H]3C,[1*]C(=O)[O-],[4*]N1CC[NH+](C)CC1',
#  '[3*]C[C@H](O)CC(=O)[O-],[4*][N+](C)(C)C',
#  '[3*]CC(=O)[O-],[4*][N+](C)(C)C',
#  '[4*][NH2+][4*],[3*]CC=C,[3*]CCCCCC[3*],[4*][N+](C)(C)C',
#  '[3*]CCCCCCCCCC[3*],[4*][N+](C)(C)C',
#  '[2*]O[2*],[3*]CC[3*],[1*]C(=O)CCC([1*])=O,[4*][N+](C)(C)C',
#  '[2*]O[2*],[3*]CC[3*],[1*]C(N)=O,[4*][N+](C)(C)C',
#  '[4*][N+]([4*])(C)C,[3*]CCCCCC[3*],[3*]C1c2ccccc2-c2ccccc21',
#  '[1*]C(=O)C([6*])([6*])O,[2*]O[2*],[12*]c1cccs1,[3*]C1C[C@@H]2[C@H]3O[C@H]3[C@H](C1)[N+]2(C)C',
#  '[1*]C(=O)C([6*])O,[2*]O[2*],[14*]c1ccccc1,[3*]C1CC2CCC(C1)[N+]2(C)C',
#  '[4*][N+]1(C)CC[C@]23c4c5ccc(O)c4O[C@H]2C(=O)CC[C@@]3(O)[C@H]1C5,[3*]C[6*],[13*]C1CC1',
#  '[5*]=C1CC[N+](C)(C)CC1,[5*]=C(c1ccccc1)c1ccccc1',
#  '[13*]C1CCCC1,[2*]O[2*],[3*]C1CC[N+](C)(C)C1,[14*]c1ccccc1,[1*]C(=O)C([6*])([6*])O',
#  '[4*][N+]1(C)CCc2cc([14*])c([14*])c([14*])c2[C@H]1C[6*],[2*]O[2*],[1*]C(=O)CCC([1*])=O,[3*]CCC[3*],[2*]OC,[14*]c1cc([14*])c([14*])c([14*])c1,[4*][N+]1(C)CCc2cc([14*])c([14*])c([14*])c2[C@@H]1C[6*]',
#  '[1*]C(=O)CCC=[5*],[2*]O[2*],[4*][N+]1(C)CCc2cc([14*])c([14*])cc2[C@H]1C[6*],[3*]CCC[3*],[2*]OC,[14*]c1cc([14*])c([14*])c([14*])c1',
#  '[4*][N+]1(C)CCc2cc([14*])c([14*])cc2C1C[6*],[2*]O[2*],[1*]C(=O)CC[3*],[2*]OC,[3*]CCCCC[3*],[14*]c1ccc([14*])c([14*])c1',
#  '[6*]C[C@H]1c2cc([14*])c([14*])cc2CC[N+]1(C)C,[2*]O[2*],[2*]OC,[6*]C[C@@H]1c2c(cc([14*])c([14*])c2[14*])CC[N+]1(C)C,[14*]c1ccc([14*])c([14*])c1,[14*]c1ccc([14*])cc1',
#  '[1*]C(=O)C([6*])([6*])O,[3*]C1CCC[N+](C)(C)C1,[14*]c1ccccc1,[2*]O[2*]',
#  '[1*]C(=O)/C(=N\\OC)c1csc(N)n1,[3*]CC1=C(C(=O)[O-])N2C(=O)[C@@H]([3*])[C@H]2SC1,[4*]N[4*],[4*][N+]1(C)CCCC1',
#  '[3*]CCCCC[3*],[4*][N+]1(C)CCCC1',
#  '[14*]c1ccccc1,[3*]CC([6*])([6*])O,[13*]C1CCCCC1,[4*]N1CC[N+](C)(C)CC1',
#  '[1*]C(=O)C([6*])([6*])O,[2*]O[2*],[14*]c1ccccc1,[3*]C1C[N+]2(C)CCC1CC2',
#  '[4*]N(C)C,[2*]O[2*],[1*]C([1*])=O,[14*]c1ccc[n+](C)c1',
#  'C[n+]1ccccc1/C=N/O',
#  '[2*]O[2*],[1*]C(=O)CC[3*],[4*][N@+]1(C)CCc2cc([14*])c([14*])cc2[C@H]1C[6*],[2*]OC,[3*]CCCCC[3*],[14*]c1ccc([14*])c([14*])c1',
#  '[3*][C@@H]1C([O-])=C(C(N)=O)C(=O)[C@@]2(O)C([O-])=C3C(=O)c4c([O-])cccc4C(=C)[C@H]3[C@H](O)[C@@H]12,[4*][NH+](C)C',
# ...
#  '[2*]O[2*],[1*]C(=O)O,[14*]c1ccccc1[14*],[1*]C(C)=O',
#  '[2*]O[2*],[7*]n1cnc2cnc(N)nc21,[3*]CC(C[3*])CC[6*],[1*]C(C)=O',
#  '[2*]O[2*],[1*]C(=O)C[3*],[11*][C@]12OC(C)(C)O[C@@H]1C[C@H]1[C@@H]3C[C@H](F)C4=CC(=O)C=C[C@]4(C)[C@@]3(F)[C@@H](O)C[C@@]12C,[1*]C(C)=O',
#  '[2*]O[2*],[1*]C(=O)C[3*],[11*][C@]12OC3(CCCC3)O[C@@H]1C[C@H]1[C@@H]3CCC4=CC(=O)C=C[C@]4(C)[C@@]3(F)[C@@H](O)C[C@@]12C,[1*]C(C)=O',
#  '[2*]O[2*],[1*]C(=O)C[3*],[13*][C@]1(O)CC[C@H]2[C@@H]3CCC4=CC(=O)CC[C@]4(C)[C@@]3(F)[C@@H](O)C[C@@]21C,[1*]C(C)=O',
#  '[2*]O[2*],[1*]C(=O)C[3*],[13*][C@]1(O)CC[C@H]2[C@@H]3CCC4=CC(=O)CC[C@]4(C)[C@H]3[C@@H](O)C[C@@]21C,[1*]C(C)=O',
#  '[2*]O[2*],[1*]C(=O)C[3*],[13*][C@]1(O)CC[C@H]2[C@@H]3CCC4=CC(=O)CC[C@]4(C)[C@H]3C(=O)C[C@@]21C,[1*]C(C)=O',
#  '[2*]O[2*],[1*]C(=O)C[3*],[13*][C@H]1CC[C@H]2[C@@H]3CCC4=CC(=O)CC[C@]4(C)[C@H]3CC[C@]12C,[1*]C(C)=O',
#  '[3*]CC1=C(C(=O)[O-])N2C(=O)[C@@H]([3*])[C@H]2SC1,[1*]C(=O)/C(=N\\OC)c1csc(N)n1,[2*]O[2*],[1*]C(C)=O,[4*]N[4*]',
#  '[3*]CC1=C(C(=O)[O-])N2C(=O)[C@@H]([3*])[C@H]2SC1,[2*]O[2*],[1*]C(C)=O,[14*]c1ccccc1,[1*]C(=O)[C@H]([6*])[NH3+],[4*]N[4*]',
#  '[12*]c1cccs1,[3*]CC1=C(C(=O)[O-])N2C(=O)[C@@H]([3*])[C@H]2SC1,[2*]O[2*],[1*]C(C)=O,[4*]N[4*],[1*]C(=O)C[6*]',
#  '[1*]C(=O)C[3*],[3*]CC1=C(C(=O)[O-])N2C(=O)[C@@H]([3*])[C@H]2SC1,[2*]O[2*],[1*]C(C)=O,[14*]c1ccncc1,[4*]N[4*],[9*]S[9*]',
#  '[2*]O[2*],[3*]CC[3*],[4*][N+](C)(C)C,[1*]C(C)=O',
#  '[4*]N1C[C@H]2[C@@H]([C@H]1[11*])C2(C)C,[1*]C(=O)[C@@H]([3*])C(C)(C)C,[1*]C([1*])=O,[4*]N[4*],[3*]C(C[6*])C(=O)C(N)=O,[13*]C1CCC1,[3*]C(C)(C)C',
#  '[11*]C1[NH2+]C([11*])C(C)(C)S1,[3*]CCCCCC(=O)[O-],[14*]c1ccccc1,[1*]C(=O)[O-],[4*]N[4*],[1*]C(=O)C([3*])[6*],[1*]C(=O)C[6*]',
#  '[4*]N1C(=C)C(C)(C)c2ccccc21,[3*]CCCCCC(=O)O',
#  '[2*]O[2*],[14*]c1ccccc1,[14*]c1cccc([14*])c1,[1*]C([1*])=O,[3*]C[6*],[13*]C1C(C=C(Cl)Cl)C1(C)C',
#  '[8*]N1C(=O)NC(C)(C)C1=O,[14*]c1ccc([N+](=O)[O-])c([14*])c1,[6*]C(F)(F)F',
#  'CN1C(=O)OC(C)(C)C1=O',
#  '[5*]=Cc1ccc(C=[5*])cc1,[5*]=C1C(=O)C2([13*])CCC1C2(C)C,[6*]CS(=O)(=O)[O-]',
#  '[3*]C1(C)C2CCC(C2)C1(C)C,[4*][NH2+]C',
#  '[3*]CCCCC=[5*],[13*][C@@H]1CC1(C)C,[4*]NC(=[5*])C(=O)[O-],[3*]C[C@H]([NH3+])C(=O)[O-],[1*]C([1*])=O,[9*]S[9*]',
#  '[12*]c1nc([12*])n2ccnc(N)c12,[6*]C1CC(C)(O)C1,[14*]c1ccccc1,[12*]c1ccc2ccc([14*])cc2n1',
#  '[14*]c1ccccc1,[6*]C1(C)CC(=O)N(C)C1=O',
#  '[11*][C@]12OC[C@H]3OC(C)(C)O[C@H]3[C@@H]1OC(C)(C)O2,[3*]C[6*],[2*]OS(N)(=O)=O',
#  'CC12CC3CC(C)(C1)CC([NH3+])(C3)C2',
#  '[2*]O[2*],[1*]C(=O)C[3*],[13*]C1CCC2C3CCC4=CC(=O)CCC4(C)C3CCC12C,[1*]C(=O)C(C)(C)C',
#  '[7*]n1cnc2c(=O)[nH]c(N)nc21,[6*]CO,[6*][C@H]1C[C@H](O)[C@H]([13*])C1=C',
#  'Cc1[nH+]cc2n1-c1ccc(Cl)cc1C(c1ccccc1F)=NC2',
#  '[14*]c1ccccc1[14*],[14*]c1ccccc1,[1*]C([1*])=O,[4*]N[4*],[4*]N1CCc2[nH]c(C)nc2-c2ccccc21,[14*]c1ccc([14*])cc1',
#  '[1*]C(C)=O,[4*]NC,[1*]C(=O)[O-],[1*]C([1*])=O,[4*]N[4*],[14*]c1c(C)c([14*])c(I)c([14*])c1I',
#  '[1*]C(=O)C1=C(C)NC(C)=C(C([1*])=O)C1[6*],[3*]CC[3*],[2*]O[2*],[14*]c1cccc([N+](=O)[O-])c1,[2*]OC,[3*]C(C)C',
#  '[1*]C(=O)C1=C(C)NC(C)=C(C([1*])=O)C1[6*],[2*]O[2*],[2*]OC,[3*]C(C)C,[14*]c1cccc2nonc12',
#  '[1*]C(=O)C1=C(C)NC(C)=C(C([1*])=O)C1[6*],[14*]c1ccccc1[N+](=O)[O-],[2*]OC',
#  '[1*]C(=O)C1=C(C)NC(C)=C(C([1*])=O)C1[6*],[14*]c1ccccc1[N+](=O)[O-],[2*]O[2*],[3*]CC(C)C,[2*]OC',
#  '[1*]C(=O)C1=C(C)NC(C)=C(C([1*])=O)C1[6*],[3*]CC[3*],[2*]O[2*],[14*]c1cccc([N+](=O)[O-])c1,[4*][NH+]([4*])C,[2*]OC,[14*]c1ccccc1,[3*]C[6*]',
#  '[3*]CC[3*],[14*]c1c([14*])c(O)c2c(c1C)COC2=O,[2*]O[2*],[2*]OC,[1*]C(=O)CCC(=[5*])C,[5*]=CC[6*],[4*]N1CCOCC1',
#  '[1*]C(C)=O,[11*][C@]1(C)CCc2c(C)c([14*])c(C)c(C)c2O1,[6*]CCC[C@H](C)CCC[C@H](C)CCCC(C)C,[2*]O[2*]',
#  '[2*]O[2*],[11*]C1(C)CCc2c(C)c([14*])c(C)c(C)c2O1,[6*]CCCC(C)CCCC(C)CCCC(C)C,[1*]C(C)=O',
#  '[14*]c1cnc(C)c(O)c1[14*],[6*]CO',
#  '[14*]c1cnc(C)c(O)c1[14*],[3*]CC[3*],[2*]OP(=O)([O-])[O-],[4*][NH+]([4*])[4*],[3*]C[6*],[3*]CC(=O)[O-],[4*]N([4*])[4*]',
#  '[5*]=CC(=[5*])C,[5*]=CC1=C(C)CCCC1(C)C,[5*]=CC(=O)[O-],[5*]=CC=[5*]',
#  '[5*]=CC(=[5*])C,[5*]=CC1=C(C)CCCC1(C)C,[5*]=CC=[5*]',
#  '[5*]=CCO,[5*]=CC(=[5*])C,[5*]=CC1=C(C)CCCC1(C)C,[5*]=CC=[5*]',
#  '[5*]=CC(=[5*])C,[5*]=CC1=C(C)CCCC1(C)C,[5*]=CC(=O)[O-],[5*]=CC=[5*]',
#  '[5*]=CC(=[5*])C,[5*]=CC1=C(C)CCCC1(C)C,[5*]=CC(=O)[O-],[5*]=CC=[5*]',
#  '[1*]C(=O)C[3*],[14*]c1c(C)cccc1C,[12*]c1ncon1,[13*]C1CCS(=O)(=O)CC1,[1*]C([1*])=O,[4*]N[4*],[14*]c1ccc([14*])cc1,[4*]N([4*])[4*]',
#  '[14*]c1c(C)cccc1Cl,[4*]N1CCN([4*])CC1,[12*]c1cnc([12*])s1,[1*]C([1*])=O,[12*]c1cc([12*])nc(C)n1,[4*]N[4*],[3*]CCO',
#  '[12*]c1noc(C)c1[14*],[14*]c1c(Cl)cccc1Cl,[1*]C(=O)[O-],[1*]C([1*])=O,[4*]N[4*],[3*][C@@H]1C(=O)N2[C@@H]1SC(C)(C)[C@@H]2[11*]',
#  '[12*]c1noc(C)c1[14*],[14*]c1ccccc1,[1*]C(=O)[O-],[1*]C([1*])=O,[4*]N[4*],[3*][C@@H]1C(=O)N2[C@@H]1SC(C)(C)[C@@H]2[11*]',
#  '[14*]c1ccc(S(N)(=O)=O)cc1,[14*]c1ccccc1,[12*]c1noc(C)c1[14*]',
#  '[1*]C(=O)[C@H](O)[C@H]([3*])[6*],[2*]O[2*],[1*]C(C)=O,[2*]OC,[3*][C@H]1C(=O)[C@@]2(C)[C@H]([C@H]([3*])[C@]3(O)C[C@@H]([3*])C(C)=C1C3(C)C)[C@]1([3*])CO[C@@H]1C[C@@H]2[3*],[14*]c1ccccc1,[1*]C([1*])=O,[4*]N[4*],[3*]C(C)(C)C',
#  '[2*]OC,[5*]=C(C)CCC(=O)[O-],[5*]=CC[6*],[14*]c1c([14*])c([O-])c2c(c1C)COC2=O',
#  '[3*]CC[3*],[2*]O[2*],[2*]OC,[1*]C(=O)CCC(=[5*])C,[4*][NH+]1CCOCC1,[5*]=CC[6*],[14*]c1c([14*])c([O-])c2c(c1C)COC2=O',
#  '[1*]C(=O)[O-],[4*]N1CC[NH2+]C(C)C1,[7*]n1cc([14*])c(=O)c2c(C)c(F)c([14*])cc21,[6*]C1CC1',
#  '[6*]C(C)O,[3*]C([6*])C,[14*]c1c(C)c2cc3nc(cc4nc(cc5[nH]c(cc1[nH]2)c(C)c5[14*])C(C)=C4CCC(=O)[O-])C(CCC(=O)[O-])=C3C,[2*]O[2*]',
#  '[1*]C(=O)CCC1=C(C)c2cc3[nH]c(cc4nc(cc5[nH]c(cc1n2)c([14*])c5C)C(C=C)=C4C)C1=CC=C(C([1*])=O)[C@H]([13*])[C@]13C,[1*]C([1*])=O,[2*]OC,[6*]CCC(=O)[O-]',
#  '[3*][C@]1([13*])CC[C@H]2[C@@H]3C=C(C)C4=CC(=O)CC[C@]4(C)[C@H]3CC[C@@]21C,[2*]O[2*],[1*]C(C)=O',
#  'Cc1cn[nH]c1',
#  '[5*]=Cc1[nH]c(C)cc1C,[5*]=C1C(=O)Nc2ccccc21',
#  '[5*]=Cc1c(C)cc([14*])c(C)c1C,[2*]OC,[5*]=CC(=O)[O-],[5*]=CC(=[5*])C,[5*]=CC=[5*]',
#  '[6*]CC1=[NH+]CCN1,[6*]C(C)(C)C,[14*]c1cc(C)c([14*])c(C)c1O',
#  '[1*]C(=O)C[3*],[4*][NH+]([4*])[4*],[3*]CC(=O)[O-],[4*]N[4*],[14*]c1c(C)cc(C)c(Br)c1C',
#  '[3*]CC(O)C[3*],[2*]O[2*],[1*]C(C)=O,[4*][NH2+][4*],[3*]C(C)C,[14*]c1cc(C)c([14*])c(C)c1C',
#  '[3*]CC1=C(C(=O)[O-])N2C(=O)[C@@H]([3*])[C@H]2SC1,[14*]c1cnc(C)cc1O,[14*]c1ccc(O)cc1,[12*]c1nnnn1C,[1*]C([1*])=O,[1*]C(=O)[C@H]([3*])[6*],[4*]N[4*],[9*]S[9*]',
#  '[4*]N(C)C,[5*]=Cc1cc(C)n([7*])c1C,[14*]c1ccccc1,[5*]=Cc1ccc2cc([14*])ccc2[n+]1C',
#  '[2*]OP(=O)([O-])[O-],[14*]c1cc(C)c([14*])c2ccccc12',
#  '[2*]O[2*],[3*]C[6*],[14*]c1cc(C)cc(C)c1,[11*]C1CNC(=O)O1',
#  '[5*]=CC#N,[12*]c1ccnc([12*])n1,[14*]c1ccc(C#N)cc1,[5*]=Cc1cc(C)c([14*])c(C)c1,[4*]N[4*]',
#  '[14*]c1ccc(C#N)cc1,[2*]O[2*],[14*]c1c(C)cc(C#N)cc1C,[4*]N[4*],[12*]c1nc([12*])c(Br)c(N)n1',
#  '[6*]C1CCCCC1,[12*]c1cc(C)cc(=O)n1[O-]',
#  '[12*]c1nc(C)cc(C)n1,[2*]O[2*],[2*]OC,[3*][C@H](C(=O)[O-])C([3*])([6*])[6*],[14*]c1ccccc1',
#  '[1*]C(=O)NNC[6*],[14*]c1ccccc1,[12*]c1cc(C)on1',
#  'CC1=CC(=O)c2ccccc2C1=O',
#  'Cc1cc2cc3c(C)cc(=O)oc3c(C)c2o1',
#  '[1*]C(=O)[O-],[14*]c1ccc(C(=C)c2cc3c(cc2C)C(C)(C)CCC3(C)C)cc1',
#  '[7*]n1c2nc(=O)[nH]c(=O)c-2nc2cc(C)c(C)cc21,[6*]C[C@H](O)[C@H](O)[C@H](O)CO',
#  '[2*]OP(=O)([O-])[O-],[7*]n1c2nc(=O)[nH]c(=O)c-2nc2cc(C)c(C)cc21,[3*]C[C@@H](O)[C@@H](O)[C@@H](O)C[6*]',
#  '[5*]=C(C)C1=N[C@@](C)(C2N=C(C(=[5*])C)[C@]([13*])(C)[C@H]2[13*])[C@]([13*])(C)[C@@H]1[13*],[2*]OP(=O)([O-])O[2*],[6*]CC(N)=O,[1*]C(=O)CC[6*],[7*]n1cnc2cc(C)c(C)cc21,[6*]CO,[3*]C[C@@H]([3*])C,[4*]N[4*],[5*]=CC1=NC(=[5*])[C@@H]([13*])C1(C)C,[6*]CCC(N)=O,[3*][C@H]1[C@@H](O)[C@@H]([6*])O[C@@H]1[11*],[5*]=C1NC(=[5*])[C@]([13*])(C)[C@@H]1[13*]',
#  'Cc1cc2c(s1)=Nc1ccccc1NC=2N1CC[NH+](C)CC1',
#  'Cc1cc2c(s1)Nc1ccccc1[NH+]=C2N1CC[NH+](C)CC1',
#  '[14*]c1ccc(Cl)c(S(N)(=O)=O)c1,[1*]C(=O)NN1c2ccccc2CC1C',
#  '[13*]C1CC1,[3*]C[6*],[4*][NH+]1CC[C@]23c4c5ccc(O)c4O[C@H]2C(=C)CC[C@@]3(O)[C@H]1C5',
#  '[3*]CCC([6*])[6*],[14*]c1cc(C)ccc1O,[4*][NH+]([4*])[4*],[14*]c1ccccc1,[3*]C(C)C',
#  '[2*]O[2*],[14*]c1cc(C)ccc1C,[3*]CCCC(C)(C)C(=O)[O-]',
#  '[14*]c1c(Cl)ccc(C)c1Cl,[14*]c1ccccc1[14*],[4*]N[4*],[1*]C(=O)[O-]',
#  '[8*]N([8*])C,[3*]C([13*])C([3*])C,[8*]N1CCCC1[11*],[2*]O[2*],[6*]C[11*],[8*]N[8*],[14*]c1c2nc3c([14*])ccc(C)c3oc-2c(C)c(=O)c1N,[6*]C([11*])[11*],[1*]C([1*])=O,[4*]N[4*],[6*]C(C)C',
#  '[5*]=Cc1cccc(C(=[5*])c2ccc(C)cc2)n1,[4*][NH+]1CCCC1,[3*]CC=[5*],[5*]=CC(=O)[O-]',
#  '[5*]=C(c1ccc(C)cc1)c1ccccn1,[4*][NH+]1CCCC1,[3*]CC=[5*]',
#  '[14*]c1ccc(C)cc1,[1*]C([1*])=O,[14*]c1cc(O)c([O-])c([N+](=O)[O-])c1',
#  '[12*]c1ccc([12*])n1C,[14*]c1ccc(C)cc1,[1*]C([1*])=O,[6*]CC(=O)[O-]',
#  '[4*]N(C)C,[14*]c1ccc(C)cc1,[1*]C(=O)C[6*],[12*]c1nc2ccc(C)cn2c1[12*]',
#  '[14*]c1ccc(S(N)(=O)=O)cc1,[14*]c1ccc(C)cc1,[6*]C(F)(F)F,[7*]n1nc([12*])cc1[12*]',
#  '[3*]CC1=[NH+]CCN1,[14*]c1cccc(O)c1,[14*]c1ccc(C)cc1,[4*]N([4*])[4*]',
#  '[1*]C(=O)N[NH+]1CCCCCC1,[10*]S(=O)(=O)c1ccc(C)cc1,[4*][N-][4*]',
#  '[6*]C(F)(F)F,[2*]O[2*],[12*]c1cc([14*])ccn1,[4*]NC,[1*]C([1*])=O,[4*]N[4*],Cc1ccc(S(=O)(=O)O)cc1,[14*]c1ccc([14*])cc1,[14*]c1ccc(Cl)c([14*])c1',
#  '[14*]c1ccc(C)c(C)c1,[7*]n1[nH]c(C)c(N/N=C2\\C=CC=C(c3cccc([14*])c3)C2=O)c1=O,[1*]C(=O)[O-]',
#  '[12*]c1ccnc([12*])n1,[14*]c1ccc(C)c([14*])c1,[7*]n1cnc(C)c1,[14*]c1cc([14*])cc([14*])c1,[1*]C([1*])=O,[4*]N[4*],[14*]c1cccnc1,[6*]C(F)(F)F',
#  '[12*]c1ccnc([12*])n1,[14*]c1ccc(C)c([14*])c1,[4*]N1CC[NH+](C)CC1,[1*]C([1*])=O,[3*]C[6*],[4*]N[4*],[14*]c1cccnc1,[14*]c1ccc([14*])cc1',
#  ...]

# %%
import codecs
from SmilesPE.tokenizer import *
clintox_smiles = df_clin['smiles'].tolist()
clintox_selfies = df_clin['selfies'].tolist()
spe_vob= codecs.open('./spe_vocab/SPE_ChEMBL.txt')
spe_vocab_smi1 = codecs.open('./spe_vocab/clin_tox21_zinc.smi')
print("spe vocab size of spe: ", len(spe_vob.readlines()))
print("spe vocab size of spe_smi1: ",len(spe_vocab_smi1.readlines()))
print("spe vocab size of spe_smi2: ",spe_smi2.get_vocab_size())
spe = SPE_Tokenizer(spe_vob)
# check validity of all fragments
for smile  in clintox_smiles:
    print(smile)
    print(spe.tokenize(smile).split(' '))
    print(spe_smi1.tokenize(smile).split(' '))
    print(spe_smi2.encode(smile).tokens)
    print('-----------------')

# %%
spe_smi2.get_vocab()
list(spe_smi2.get_vocab().keys())
